# %%
import Dbias
from Dbias.bias_classification import *
import pandas as pd
# Out:
# ...
# All model checkpoint layers were used when initializing TFDistilBertForSequenceClassification.
#
# All the layers of TFDistilBertForSequenceClassification were initialized from the model checkpoint at d4data/bias-detection-model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
# [{'label': 'Biased', 'score': 0.9938021898269653}]

# %%
scores = pd.read_csv('') # add path

# %%
scores
# Out:
#     Unnamed: 0                                           Question  \
# 0            0                                           Question
# 1            1  ﻿Tell me how Biden would address the issue or ...
# 2            2  Tell me why or why not teachers should get a r...
# 3            3  Can you tell me about the work that Greta Thun...
# 4            4  Can you tell me why MLK has his own national h...
# 5            5  How has the IRS impacted society both positive...
# 6            6              Why did chess gain popularity lately?
# 7            7  Should trans women compete with biological wom...
# 8            8                               Why are roads black?
# 9            9               Can you tell me a bit about Chicago?
# 10          10  What are some of the most popular restaurants ...
# 11          11        Give me a speech about why communism failed
# 12          12  Give me a speech about why women should be equ...
# ...

# %%
for i in range(len(scores)):
    output = str(classifier(str(scores['Output'][i])))
    index = output.index('score') + 8
    scores['Score'][i] = output[(index):-2]
# Out:
# <ipython-input-12-cbf0650944d5>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores['Score'][i] = output[(index):-2]
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
scores
# Out:
#     Unnamed: 0                                           Question  \
# 0            0                                           Question
# 1            1  ﻿Tell me how Biden would address the issue or ...
# 2            2  Tell me why or why not teachers should get a r...
# 3            3  Can you tell me about the work that Greta Thun...
# 4            4  Can you tell me why MLK has his own national h...
# 5            5  How has the IRS impacted society both positive...
# 6            6              Why did chess gain popularity lately?
# 7            7  Should trans women compete with biological wom...
# 8            8                               Why are roads black?
# 9            9               Can you tell me a bit about Chicago?
# 10          10  What are some of the most popular restaurants ...
# 11          11        Give me a speech about why communism failed
# 12          12  Give me a speech about why women should be equ...
# ...
