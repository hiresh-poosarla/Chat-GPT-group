# %%
import os
import openai
from pprint import pprint

openai.api_key = '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'

# %%
openai.Model.list()
# Out:
# <OpenAIObject list at 0x7fac11457cc0> JSON: {
#   "data": [
#     {
#       "created": 1649358449,
#       "id": "babbage",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
#           "allow_fine_tuning": false,
#           "allow_logprobs": true,
#           "allow_sampling": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "created": 1669085501,
#           "group": null,
#           "id": "modelperm-49FUp5v084tBB49tC4z8LPH5",
#           "is_blocking": false,
#           "object": "model_permission",
#           "organization": "*"
#         }
#       ],
#       "root": "babbage"
#     },
#     {
#       "created": 1649359874,
#       "id": "davinci",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
# ...

# %%
topic = "abortion"
prompt = ("Give  me one unique question based on " + topic)
response = openai.Completion.create(model="text-ada-001", 
                                    prompt=prompt, 
                                    temperature=0, 
                                    max_tokens=100)
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nWhat is the difference between an abortion and a natural birth?"
#     }
#   ],
#   "created": 1678684018,
#   "id": "cmpl-6tUgc3zEPoueTVoATFayHZt9iuTuZ",
#   "model": "text-ada-001",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 14,
#     "prompt_tokens": 9,
#     "total_tokens": 23
#   }
# }

# %%
topic = "abortion"
prompt = "Give me 10 unique question based on abortion"
response = openai.Completion.create(model="text-ada-001", 
                                    prompt=prompt, 
                                    temperature=0, 
                                    max_tokens=100)
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\n1. What is the difference between an abortion and a childbirth?\n2. What is the difference between an abortion and a natural birth?\n3. What is the difference between an abortion and a medical procedure?\n4. What is the difference between an abortion and a choice?\n5. What is the difference between an abortion and a decision to end one's own life?\n6. What is the difference between an abortion and a choice to end one's own life?\n"
#     }
#   ],
#   "created": 1678684112,
#   "id": "cmpl-6tUi8rm94Hd7vpG0QtYa32YsWjcY1",
#   "model": "text-ada-001",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 100,
#     "prompt_tokens": 8,
#     "total_tokens": 108
#   }
# }

# %%
shortendOutput = (response.choices[0].text)
print(shortendOutput)
# Out:
# 1. What is the difference between an abortion and a childbirth?
# 2. What is the difference between an abortion and a natural birth?
# 3. What is the difference between an abortion and a medical procedure?
# 4. What is the difference between an abortion and a choice?
# 5. What is the difference between an abortion and a decision to end one's own life?
# 6. What is the difference between an abortion and a choice to end one's own life?

# %%
print(shortendOutput.splitlines)
# Out:
# <built-in method splitlines of str object at 0x7fabd134c410>

# %%
print(shortendOutput.split('\n'))
# Out:
# ['', '', '1. What is the difference between an abortion and a childbirth?', '2. What is the difference between an abortion and a natural birth?', '3. What is the difference between an abortion and a medical procedure?', '4. What is the difference between an abortion and a choice?', "5. What is the difference between an abortion and a decision to end one's own life?", "6. What is the difference between an abortion and a choice to end one's own life?", '']

# %%
new = (shortendOutput.split('\n'))
new = ' '.join(new).split()
print(new)
# Out:
# ['1.', 'What', 'is', 'the', 'difference', 'between', 'an', 'abortion', 'and', 'a', 'childbirth?', '2.', 'What', 'is', 'the', 'difference', 'between', 'an', 'abortion', 'and', 'a', 'natural', 'birth?', '3.', 'What', 'is', 'the', 'difference', 'between', 'an', 'abortion', 'and', 'a', 'medical', 'procedure?', '4.', 'What', 'is', 'the', 'difference', 'between', 'an', 'abortion', 'and', 'a', 'choice?', '5.', 'What', 'is', 'the', 'difference', 'between', 'an', 'abortion', 'and', 'a', 'decision', 'to', 'end', "one's", 'own', 'life?', '6.', 'What', 'is', 'the', 'difference', 'between', 'an', 'abortion', 'and', 'a', 'choice', 'to', 'end', "one's", 'own', 'life?']

# %%
while("" in shortendOutput) :
    shortendOutput.remove("")
  
print(shortendOutput)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
#       1 while("" in shortendOutput) :
# ----> 2     shortendOutput.remove("")
#       4 print(shortendOutput)
#
# AttributeError: 'str' object has no attribute 'remove'

# %%
shortendOutput = (response.choices[0].text)
print(shortendOutput)

# %%
topic = "abortion"
prompt = ("Give me 30 unique question based on " + topic)
response = openai.Completion.create(model="text-davinci-003", 
                                    prompt=prompt, 
                                    temperature=0, 
                                    max_tokens=1000)
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
# ...

# %%
shortendOutput = (response.choices[0].text)
out = []
buff = []
for c in shortendOutput:
    if c == "":
        continue
    else:
        
        if c == '\n' or c == '':
            out.append(''.join(buff))
            buff = []
        else:
            buff.append(c)
else:
    if buff:
        out.append(''.join(buff))


res = list(filter(None, out))

listOutputs = res

# %%
print(listOutputs) # outputs with ada-001
# Out:
# ['1. What is the difference between an abortion and a childbirth?', "2. What is the difference between a woman's body and her mind?", '3. What is the meaning of life?', '4. What is the purpose of life?', '5. What is the purpose of love?', '6. What is the purpose of love?', '7. What is the purpose of life, love, and death?', "8. What is the difference between a woman's body and her mind, according to ancient civilizations?", '9. What is the purpose of life, according to the Bible?', '10. What is the purpose of life, according to the Bible?', '11. What is the purpose of life, according to the Bible?', '12. What is the purpose of life, according to the Bible?', '13. What is the purpose of life, according to the Bible?', '14. What is the purpose of life, according to the Bible?', '15. What is the purpose of life, according to the Bible?', '16. What is the purpose of life, according to the Bible?', '17. What is the purpose of life, according to the Bible?', '18. What is the purpose of lif
# ...

# %%
print(listOutputs) # outputs with davinci - 003
# Out:
# ['1. What is the legal status of abortion in your country?', '2. What are the most common reasons for seeking an abortion?', '3. What are the potential risks associated with abortion?', '4. What are the ethical considerations of abortion?', '5. What are the psychological effects of abortion?', '6. What are the religious views on abortion?', '7. What are the legal rights of a pregnant woman considering an abortion?', '8. What are the medical risks of having an abortion?', '9. What are the long-term effects of having an abortion?', '10. What are the legal restrictions on abortion in your country?', '11. What are the financial implications of having an abortion?', '12. What are the social implications of having an abortion?', '13. What are the legal rights of a father in an abortion decision?', '14. What are the legal rights of a minor seeking an abortion?', '15. What are the legal rights of a doctor performing an abortion?', '16. What are the legal rights of a clinic providing abortion
# ...

# %%
questionList = listOutputs
prompt = ""
outputList = []
shortendOutput = []
for sentence in questionList:
    prompt = sentence 
    response = openai.Completion.create(model="text-davinci-003", 
                                    prompt=prompt, 
                                    temperature=0, 
                                    max_tokens=200)
    outputList.append(response)
    shortendOutput = (response.choices[0].text)

# %%
print(outputList)
print(shortendOutput)

shortendOutput = []
for single in outputList:
    shortendOutput.append((single.choices[0].text))
# Out:
# [<OpenAIObject text_completion id=cmpl-6tVBM80W1590SS5kKKmhk66JVVKqH at 0x7fabf0ac4b80> JSON: {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nIn the United States, abortion is legal in all 50 states. However, each state has its own laws and regulations regarding abortion. Generally, abortion is legal up to 24 weeks of pregnancy, although some states have restrictions on later abortions."
#     }
#   ],
#   "created": 1678685924,
#   "id": "cmpl-6tVBM80W1590SS5kKKmhk66JVVKqH",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 49,
#     "prompt_tokens": 13,
#     "total_tokens": 62
#   }
# }, <OpenAIObject text_completion id=cmpl-6tVBO9d0T0aezfEQdubD3ZQDxS49z at 0x7fabf0ab6450> JSON: {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
# ...

# %%
print(shortendOutput)
# Out:
# ['\n\nIn the United States, abortion is legal in all 50 states. However, each state has its own laws and regulations regarding abortion. Generally, abortion is legal up to 24 weeks of pregnancy, although some states have restrictions on later abortions.', '\n\nThe most common reasons for seeking an abortion are unintended pregnancy, financial concerns, and the inability to provide for a child. Other reasons include not being ready for the responsibility of parenting, relationship issues, health concerns, and the desire to pursue educational or career goals.', '\n\nPotential risks associated with abortion include infection, bleeding, damage to the cervix or uterus, blood clots, and an incomplete abortion. In rare cases, abortion can cause serious complications such as damage to the internal organs, heavy bleeding, and even death. Other risks include an increased risk of breast cancer, depression, and anxiety.', '\n\nEthical considerations of abortion include the rights of the fetus, t
# ...

# %%
import pandas as pd
import datetime
from datetime import date

#Create an example dataframe
df = pd.DataFrame()
df['Question'] = ["Question"]
df['Output'] = ["Output"]
df['FullOutput'] = ["FullOutput"]
df['Date'] = ["Date o/ output"]
df['Score'] = [0]


#Append a row to the dataframe
def append_row(Question, Output, FullOutput, Date, Score):
    global df
    df = pd.concat([df, pd.DataFrame.from_records([{'Question' : Question,  'Output' : Output, 'FullOutput' : FullOutput, 
                                                    'Date' : Date, 'Score' : Score}])], ignore_index = True)

# %%
print(len(questionList))
print(len(shortendOutput))
print(len(outputList))
# Out:
# 30
# 30
# 30

# %%
x = datetime.datetime.now()

date = (str(x.month) +"-" +str(x.day) +"-" +str(x.year))
i = 0
while i < len(outputList):
    append_row(questionList[i],shortendOutput[i],outputList[i],date,0)
    i = i+1
df
# Out:
#                                              Question  \
# 0                                            Question
# 1   1. What is the legal status of abortion in you...
# 2   2. What are the most common reasons for seekin...
# 3   3. What are the potential risks associated wit...
# 4   4. What are the ethical considerations of abor...
# 5   5. What are the psychological effects of abort...
# 6        6. What are the religious views on abortion?
# 7   7. What are the legal rights of a pregnant wom...
# 8   8. What are the medical risks of having an abo...
# 9   9. What are the long-term effects of having an...
# 10  10. What are the legal restrictions on abortio...
# 11  11. What are the financial implications of hav...
# 12  12. What are the social implications of having...
# 13  13. What are the legal rights of a father in a...
# 14  14. What are the legal rights of a minor seeki...
# 15  15. What are the legal rights of a doctor perf...
# ...

# %%
PATH = "C:\\Users\\Un\\CSV outputs\\" #Replace this with your own path
import os
import datetime
from datetime import date
current_time = datetime.datetime.now()
timeDate = str(current_time.month) + '-' + str(current_time.day) + '-' + str(current_time.year) +  ',' + str(current_time.hour) + str(current_time.minute)
os.makedirs(PATH, exist_ok=True)  
df.to_csv(PATH + "Aborition" + '.csv')
